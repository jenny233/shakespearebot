# %%
import os
import numpy as np
from IPython.display import HTML

import HMM
from HMM_helper import (
    text_to_wordcloud,
    states_to_wordclouds,
    parse_observations,
    sample_sentence,
    visualize_sparsities,
    animate_emission
)

import preprocessing as pp

# %%
word_list = pp.list_of_words()   # id   --> word
word_id = pp.word_id()           # word --> id
word_sylls = pp.word_syllables() # word --> n_syllables


poem_lines = pp.load_poems("shakespeare.txt")
rhyme_pairs = pp.rhyme_pairs(poem_lines)

# Train HMM
hmm = HMM.unsupervised_HMM(poem_lines, 10, 10)
# Out:
# Iteration: 10, 100%

# %%
wordclouds = states_to_wordclouds(hmm, word_id)
